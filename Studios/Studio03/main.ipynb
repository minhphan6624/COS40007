# %% [markdown]
# # Importing libraires

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1 - Data processing

# %%
#Concatenating the data
file_paths = [f'ampc/w{i}.csv' for i in range(1, 5)]

data = pd.concat([pd.read_csv(f) for f in file_paths], ignore_index=True)

data.to_csv('./combined_data.csv', index = False)

data.head()
# Out:
#    acc_mean_x_right  acc_mean_y_right  acc_mean_z_right  acc_mean_xyz_right  \
# 0          -0.17330           0.14864           0.98128              1.1065
# 1          -0.40618           0.24715           0.79471              1.0178
# 2          -0.49670           0.37167           0.70283              1.0402
# 3          -0.28780           0.15882           0.91688              1.0974
# 4          -0.56189           0.36946           0.68668              1.3085
#
#    acc_mean_xy_right  acc_mean_yz_right  acc_mean_zx_right  \
# 0            0.44735            1.06110            1.03320
# 1            0.52388            0.86595            0.96693
# 2            0.68213            0.80958            0.96510
# 3            0.50834            1.02760            0.99884
# 4            0.91759            1.02180            1.12010
#
#    acc_mean_pitch_right  acc_mean_roll_right  acc_std_x_right  ...  \
# 0                9.9751               52.281          0.25398  ...
# 1              -30.4210               48.213          0.26456  ...
# 2              -23.0680               52.897          0.35638  ...
# 3                3.2451               31.009          0.29577  ...
# 4              -24.1180               47.579          0.56810  ...
#
#    gyro_max_yz_left  gyro_max_zx_left  gyro_peak_x_left  gyro_peak_y_left  \
# 0            137.85            79.286                 4                 4
# 1            269.08           103.560                 3                 1
# 2            158.42           114.700                 2                 3
# 3            283.65           120.460                 3                 2
# 4            199.69            93.039                 4                 2
#
#    gyro_peak_z_left  gyro_peak_xyz_left  gyro_peak_xy_left  gyro_peak_yz_left  \
# 0                 3                   2                  2                  2
# 1                 2                   2                  2                  2
# 2                 2                   1                  1                  2
# 3                 2                   3                  4                  3
# 4                 2                   3                  3                  3
#
#    gyro_peak_zx_left  class
# 0                  4      2
# 1                  1      2
# 2                  2      2
# 3                  2      2
# 4                  2      2
#
# [5 rows x 157 columns]

# %%
shuffled_data = data.sample(n=len(data)).reset_index(drop=True)

shuffled_data.to_csv('./all_data.csv', index = False)

shuffled_data.head()
# Out:
#    acc_mean_x_right  acc_mean_y_right  acc_mean_z_right  acc_mean_xyz_right  \
# 0          0.640990           0.45412          0.719600              1.1777
# 1         -0.453110           0.38586          0.745280              1.1791
# 2         -0.905430           0.44620         -0.238230              1.0684
# 3         -0.080558          -0.82512          0.624560              1.2407
# 4         -0.649830          -0.85104         -0.052758              1.1677
#
#    acc_mean_xy_right  acc_mean_yz_right  acc_mean_zx_right  \
# 0            0.90859            0.92558            1.00340
# 1            0.86289            0.92770            1.02440
# 2            1.01360            0.56230            0.96460
# 3            0.99363            1.11620            0.84994
# 4            1.11700            0.92099            0.74269
#
#    acc_mean_pitch_right  acc_mean_roll_right  acc_std_x_right  ...  \
# 0               64.4410               45.162         0.302800  ...
# 1              -15.7220               50.772         0.510340  ...
# 2              -63.0200               30.880         0.093662  ...
# 3                6.9487              -51.026         0.528190  ...
# 4              -36.0700              -46.924         0.329350  ...
#
#    gyro_max_yz_left  gyro_max_zx_left  gyro_peak_x_left  gyro_peak_y_left  \
# 0           230.410           135.680                 2                 2
# 1           324.060           119.330                 3                 3
# 2            59.732            25.927                 4                 2
# 3           200.350           196.510                 5                 5
# 4           196.330           197.020                 3                 2
#
#    gyro_peak_z_left  gyro_peak_xyz_left  gyro_peak_xy_left  gyro_peak_yz_left  \
# 0                 4                   3                  2                  3
# 1                 4                   2                  3                  2
# 2                 1                   1                  3                  1
# 3                 4                   6                  6                  5
# 4                 2                   3                  5                  2
#
#    gyro_peak_zx_left  class
# 0                  3      2
# 1                  2      2
# 2                  1      2
# 3                  5      2
# 4                  2      2
#
# [5 rows x 157 columns]

# %% [markdown]
# # 2 - Model Training

# %% [markdown]
# ### Split features and target variable

# %%
from sklearn.model_selection import train_test_split

# Split features and target vairable
X = shuffled_data.drop('class', axis=1)
y = shuffled_data['class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %% [markdown]
# ### Initialize and train model without parameter tuning

# %%
from sklearn import svm
from sklearn.metrics import accuracy_score

clf = svm.SVC() # Linear Kernel
clf.fit(X_train, y_train) # Training the model
y_pred = clf.predict(X_test) # Predicting the model
accuracy_score = accuracy_score(y_test, y_pred) # Calculating the accuracy of the model

f"Accuracy of the model: {accuracy_score}"
# Out:
# 'Accuracy of the model: 0.8950988822012038'

# %% [markdown]
# ### 10 fold cross validation

# %%
from sklearn.model_selection import cross_val_score
from sklearn import svm

clf = svm.SVC()
scores = cross_val_score(clf, X, y, cv = 10) # 10-fold cross validation

scores
# Out:
# array([0.88907997, 0.8822012 , 0.90455718, 0.88736028, 0.88993981,
#        0.89595873, 0.89853826, 0.88048151, 0.88736028, 0.90017212])

# %% [markdown]
# # 3 - Hyperparameter Tuning

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
 # Radial Basis Function kernel
param_grid = {
    'C' : [0.1, 1, 10, 100, 1000],
    'gamma' : [1, 0.1, 0.01, 0.001, 0.0001],
    'kernel' : ['rbf']
}

grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3)

grid.fit(X_train, y_train)

grid.best_params_
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.834 total time=   9.5s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.834 total time=   9.5s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.834 total time=   9.6s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.834 total time=   9.5s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.834 total time=   9.7s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.834 total time=   9.4s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.834 total time=   9.6s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.834 total time=   9.6s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.834 total time=  11.3s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.834 total time=  10.4s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.834 total time=  19.1s
# [CV 2/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.834 total time=   9.5s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.834 total time=   9.5s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.834 total time=   7.8s
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.834 total time=11.6min
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.834 total time=  11.7s
# [CV 2/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.834 total time=  10.7s
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.834 total time=   9.7s
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.834 total time=   9.5s
# [CV 5/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.834 total time=  10.2s
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.835 total time=   9.7s
# [CV 2/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.834 total time=   9.8s
# [CV 3/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.835 total time=   9.9s
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.836 total time=   9.7s
# [CV 5/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.834 total time=   9.7s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.834 total time=  10.1s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.834 total time=   9.9s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.834 total time=  10.3s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.834 total time=  10.2s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.834 total time=  10.5s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.834 total time=  10.0s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.834 total time=  10.0s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.834 total time=  10.1s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.834 total time=   9.8s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.834 total time=  10.0s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.834 total time=   9.9s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.834 total time=  10.3s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.834 total time=  10.5s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.834 total time=   9.9s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.834 total time=   9.8s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.835 total time=  10.1s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.834 total time=  10.3s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.836 total time=  10.2s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.837 total time=  10.1s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.835 total time=  10.0s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.842 total time=  10.0s
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.838 total time=  10.0s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.839 total time=  10.7s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.840 total time=  11.0s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.842 total time=  10.2s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.834 total time=  12.1s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.834 total time=  10.2s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.834 total time=  10.2s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.834 total time=  10.5s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.834 total time=  10.5s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.834 total time=  10.5s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.834 total time=  10.5s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.834 total time=  10.4s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.834 total time=  10.1s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.834 total time=  10.1s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.834 total time=  10.1s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.834 total time=  10.4s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.834 total time=  10.4s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.834 total time=  10.6s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.834 total time=  10.4s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.835 total time=  10.4s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.834 total time=  10.4s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.836 total time=  10.3s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.837 total time=  10.4s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.835 total time=  10.3s
# [CV 1/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.842 total time=  10.7s
# [CV 2/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.841 total time=  10.5s
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.840 total time=  10.8s
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.840 total time=  10.7s
# [CV 5/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.842 total time=  10.8s
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.834 total time=  10.3s
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.834 total time=  10.1s
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.834 total time=  11.3s
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.834 total time=  10.1s
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.834 total time=  10.1s
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.834 total time=  10.3s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.834 total time=  10.6s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.834 total time=  10.4s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.834 total time=  10.6s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.834 total time=  10.2s
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.834 total time=  10.1s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.834 total time=  10.0s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.834 total time=  10.2s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.834 total time=  10.5s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.834 total time= 8.6min
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.835 total time=  10.4s
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.834 total time=  10.4s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.836 total time=  10.6s
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.837 total time=15.0min
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.835 total time=  12.5s
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.842 total time=  10.5s
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.841 total time=  10.5s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.840 total time=  10.6s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.840 total time=  10.4s
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.842 total time=  10.3s
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.834 total time=  10.1s
# [CV 2/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.834 total time=  10.0s
# [CV 3/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.834 total time=  10.1s
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.834 total time=  10.0s
# [CV 5/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.834 total time=  10.2s
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.834 total time=  11.1s
# [CV 2/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.834 total time=  10.3s
# [CV 3/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.834 total time=  10.4s
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.834 total time=  10.6s
# [CV 5/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.834 total time=  10.3s
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.834 total time=  10.4s
# [CV 2/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.834 total time=  10.1s
# [CV 3/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.834 total time=  10.4s
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.834 total time=  10.2s
# [CV 5/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.834 total time=  10.6s
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.835 total time=  10.9s
# [CV 2/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.834 total time=  10.5s
# [CV 3/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.836 total time=  10.3s
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.837 total time=  10.3s
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.835 total time=  10.2s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.842 total time=  11.9s
# [CV 2/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.841 total time=  10.4s
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.840 total time=  10.4s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.840 total time=  10.4s
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.842 total time=  10.4s
# {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}

# %% [markdown]
# ### Re-run prediction and check new model accuracy

# %%
grid_prediction = grid.predict(X_test)

# Evaluating the model that uses the best parameters
new_accuracy_score = accuracy_score(y_test, grid_prediction) # Calculating the accuracy of the model

f"Accuracy of the model using the best parameter: {new_accuracy_score}"


# 10-fold cross validation
scores = cross_val_score(grid, X, y, cv = 10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 4
#       1 grid_prediction = grid.predict(X_test)
#       3 # Evaluating the model that uses the best parameters
# ----> 4 new_accuracy_score = accuracy_score(y_test, grid_prediction) # Calculating the accuracy of the model
#       6 f"Accuracy of the model using the best parameter: {new_accuracy_score}"
#
# TypeError: 'numpy.float64' object is not callable

# %% [markdown]
# # 4 - Feature Selection

# %%
from sklearn.feature_selection import VarianceThreshold
